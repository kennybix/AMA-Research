# %%
# import the libraries
import numpy as np
import pandas as pd 

# data = pd.read_excel("Concrete_Data.xls")
data = np.loadtxt("concrete_data.txt")
# print(data.head(5))
x_data = data[:,:-1]
y_data = data[:,-1]

# %%
print(x_data.shape)
# Out:
# (1030, 8)

# %%
print(y_data.shape)
# Out:
# (1030,)

# %%
whole_data = {"x_data":x_data, "y_data":y_data}

# %%
from active_learning import adsp_r as AL

model = AL.active_learn(whole_data,20,0.05,1000)

# %%
x,y = model.get_more_samples()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d4b23697a491> in <module>
# ----> 1 x,y = model.get_more_samples()
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\adsp_r.py in get_more_samples(self)
#     249                 # x_new = np.array(self.x_data[new_point_loc])
#     250                 # y_new = np.array(self.y_data[new_point_loc])
# --> 251                 res = cNM.constrNM(self.loss_func,starting_point,self.LB,self.UB,full_output=True)
#     252
#     253                 # neg_acq_func = res['fopt']
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\constrNMPy.py in constrNM(func, x0, LB, UB, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback)
#      71
#      72     # Call fmin
# ---> 73     res=sciopt.fmin(constrObjFunc,x0,args=opts,ftol=ftol,xtol=xtol,maxiter=maxiter,disp=disp,
#      74          full_output=full_output,callback=callback,maxfun=maxfun,retall=retall)
#      75
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     575             'initial_simplex': initial_simplex}
#     576
# --> 577     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     578     if full_output:
#     579         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     779                     for j in one2np1:
#     780                         sim[j] = sim[0] + sigma * (sim[j] - sim[0])
# --> 781                         fsim[j] = func(sim[j])
#     782
#     783         ind = np.argsort(fsim)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     459     def function_wrapper(*wrapper_args):
#     460         ncalls[0] += 1
# --> 461         return function(*(wrapper_args + args))
#     462
#     463     return ncalls, function_wrapper
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\constrNMPy.py in constrObjFunc(x, func, LB, UB, args)
#     124     #raw_input()
#     125
# --> 126     return func(x,*args)
#     127
#     128 def transformX(x,LB,UB,offset=1E-20):
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\adsp_r.py in loss_func(self, x)
#     142         # fmin = self.gp_old.get_fmin()
#     143         x = x.reshape(1,self.dim)
# --> 144         x = self.closest(self.x_scaling_model.transform(self.x_data),self.x_scaling_model.transform(x)) #get the similar value of x in the real dataset
#     145
#     146         fhat,s2 = self.gp_old.predict(x) #modify predict to return two values just for this process
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\adsp_r.py in closest(self, points, x)
#     119         normalized_closest_point = sorted(points, key=lambda p: np.linalg.norm(p-x))[:1] # 1 for top one
#     120         denormalized_closest_point = (self.x_scaling_model).inverse_transform(normalized_closest_point)
# --> 121         denormalized_closest_point = self.closest_final(self.whole_data["x_data"],denormalized_closest_point)
#     122         return denormalized_closest_point
#     123
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\adsp_r.py in closest_final(self, points, x)
#     103         #     x = x
#     104
# --> 105         closest_point = sorted(points, key=lambda p: np.linalg.norm(p-x))[:1] # 1 for top one
#     106         return closest_point
#     107
#
# ~\OneDrive - HKUST Connect\Algorithmic Development\Paper Preparation\Paper 2\Labs\active_learning\adsp_r.py in <lambda>(p)
#     103         #     x = x
#     104
# --> 105         closest_point = sorted(points, key=lambda p: np.linalg.norm(p-x))[:1] # 1 for top one
#     106         return closest_point
#     107
#
# <__array_function__ internals> in norm(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2527                 sqnorm = dot(x.real, x.real) + dot(x.imag, x.imag)
#    2528             else:
# -> 2529                 sqnorm = dot(x, x)
#    2530             ret = sqrt(sqnorm)
#    2531             if keepdims:
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
x_train = pd.read_csv("optimal_x.csv",header=None)
y_train = pd.read_csv("optimal_y.csv",header=None)
x_test = pd.read_csv("x_test.csv",header=None)
y_test = pd.read_csv("y_test.csv",header=None)

# %%
from smt.surrogate_models import KRG as SMT_KRG
from sklearn.metrics import r2_score
smt_model = SMT_KRG(corr='abs_exp')
smt_model.set_training_values(np.array(x_train),np.array(y_train))
smt_model.train()
smt_model_y_test = smt_model.predict_values(np.array(x_data))
R2 = r2_score(y_data,smt_model_y_test)
print(R2)
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.0924222
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156245
#
#    Prediction time/pt. (sec) :  0.0000152
#
# 0.8256409000891327

# %%
# squar_exp matern52
from sklearn.model_selection import train_test_split
dataset = np.loadtxt("concrete_data.txt")
x_data = dataset[:,:-1]
y_data = dataset[:,-1] 
loop = 20
R2_set = []
for l in range(loop):
    Xtrain, Xtest, ytrain, ytest = train_test_split(x_data, y_data,train_size=149)
    smt_model_1 = SMT_KRG(corr='abs_exp')
    smt_model_1.set_training_values(np.array(Xtrain),np.array(ytrain))
    smt_model_1.train()
    # smt_model_1_y_test = smt_model_1.predict_values(np.array(Xtest))
    # R2 = r2_score(ytest,smt_model_1_y_test)
    smt_model_1_y_test = smt_model_1.predict_values(np.array(x_data))
    R2 = r2_score(y_data,smt_model_1_y_test)
    R2_set.append(R2)
print(R2_set)
print("Mean R2: {}".format(np.average(R2_set)))
# Out:
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0877581
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0149992
#
#    Prediction time/pt. (sec) :  0.0000146
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0841649
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0185263
#
#    Prediction time/pt. (sec) :  0.0000180
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1078007
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0031600
#
#    Prediction time/pt. (sec) :  0.0000031
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1109495
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0164001
#
#    Prediction time/pt. (sec) :  0.0000159
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0937533
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156240
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0910559
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0275905
#
#    Prediction time/pt. (sec) :  0.0000268
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0748627
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156271
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1026356
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0150027
#
#    Prediction time/pt. (sec) :  0.0000146
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0875916
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156343
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1045177
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0179985
#
#    Prediction time/pt. (sec) :  0.0000175
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0772698
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156252
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0879340
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0255921
#
#    Prediction time/pt. (sec) :  0.0000248
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0723298
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156221
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1041064
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0198686
#
#    Prediction time/pt. (sec) :  0.0000193
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.0731592
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0156269
#
#    Prediction time/pt. (sec) :  0.0000152
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1083846
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0139973
#
#    Prediction time/pt. (sec) :  0.0000136
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.1002631
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0150006
#
#    Prediction time/pt. (sec) :  0.0000146
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.0728402
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0296197
#
#    Prediction time/pt. (sec) :  0.0000288
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
# Warning: multiple x input features have the same value (at least same row twice).
#    Training - done. Time (sec):  0.0988600
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0219989
#
#    Prediction time/pt. (sec) :  0.0000214
#
# ___________________________________________________________________________
#
#                                   Kriging
# ___________________________________________________________________________
#
#  Problem size
#
#       # training points.        : 149
#
# ___________________________________________________________________________
#
#  Training
#
#    Training ...
#    Training - done. Time (sec):  0.1199992
# ___________________________________________________________________________
#
#  Evaluation
#
#       # eval points. : 1030
#
#    Predicting ...
#    Predicting - done. Time (sec):  0.0140002
#
#    Prediction time/pt. (sec) :  0.0000136
#
# [0.8404008824724166, 0.7804734239536372, 0.8765127347519784, 0.8020268691769413, 0.8750596248553822, 0.7931054837268203, 0.849503248424998, 0.8633619563747992, 0.8799752418921265, 0.8721806827956351, 0.8022807753646644, 0.872347756567563, 0.8600515404235864, 0.8202484477449118, 0.8764032452501245, 0.8246778752317537, 0.8781158103971493, 0.8780319564503094, 0.7625609230049151, 0.8507126455029855]
# Mean R2: 0.8429015562181348
